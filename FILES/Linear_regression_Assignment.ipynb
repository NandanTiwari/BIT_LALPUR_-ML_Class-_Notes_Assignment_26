# %% [markdown]
# ### `Import necessary libraries`

# %% [markdown]
# ### `Fetch Califonia House Price Dataset from Sklear.Dataset`

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing(as_frame=True)
print(housing.data.shape, housing.target.shape)
print(housing.feature_names[0:6])
# Out:
# (20640, 8) (20640,)
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup']

# %% [markdown]
# #### `Create Data in Pandas DataFrame`

# %% [markdown]
# #### `Explore data`

# %% [markdown]
# #### `Plot Feature Vs Target`
# * use Scatter plot

# %% [markdown]
# #### `Select any to columns  as feature and price as target`

# %% [markdown]
# #### `Train Linear Regression model using Gradient Descent`

# %% [markdown]
# #### `check MSE, R^2 Score`

# %% [markdown]
# ### `Import Linear_Regression model fom sklearn, split data into 70,30 and train the model on whole feature.`

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
