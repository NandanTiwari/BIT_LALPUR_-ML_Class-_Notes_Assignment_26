# %% [markdown]
# # `Linear Algebra for Machine Learning (ML)`
#
# ---
#
# ### Outcomes of This Class
#
# After completing this notebook, you will be able to:
# - Understand why Mathematics is important for ML.
# - Understand what Algebra is.
# - Understand what Linear Algebra is.
# - You will be able to explain why Linear Algebra is important in ML.
# - Identify the major components of Linear Algebra.
# - Understand Scalars, Vectors, and Matrices.
# - Create vectors and matrices using NumPy.
# - Perform basic vector and matrix operations.
# - Develop mathematical intuition using real-life examples.
#
# ---

# %% [markdown]
# ## `Let Understand Mathematics first`

# %% [markdown]
# ### `What is Mathematics?`
#
# Mathematics is a `language` that helps us describe the world. Using `numbers`, `symbols`, and `equations`, it provides a structured way to represent relationships and patterns. By applying `logical reasoning`, mathematics allows us to solve problems, make predictions, and explore concepts in a clear and concise manner.
#
# Different branches of mathematics solve different types of problems.
#
# Some important branches are:
#
# - `Arithmetic` → Numbers and calculations
# - `Algebra` → Variables and equations
# - `Geometry` → Shapes and space
# - `Calculus` → Change and motion
# - `Probability` → Chance and uncertainty
# - `Statistics` → Data analysis
# - `Linear Algebra` → Data, vectors and transformations
#
# ML mainly depends on:
#
# - `Linear Algebra`
# - `Calculus`
# - `Probability`
# - `Statistics`
#
# Among these, **Linear Algebra is the backbone of ML.**

# %% [markdown]
# ### Our Main Focus for this Class is `Linear Algebra`

# %% [markdown]
# #### `What is Algebra?`
# Algebra is a branch of mathematics that represents numbers using symbols (usually letters).
#
# In linear algebra, instead of writing:

# %% [markdown]
# 99 + 1 = 100

# %% [markdown]
# #### `we write`

# %% [markdown]
# x + 1 = 100
# ##### Now our goal is to find the unknown value (x).
# x = 100 - 1
#
# x = 99
#
# Here, `algebra` allows us to describe relationships between quantities.
#
# Other examples:
#
# * Distance = Speed × Time
#
# * Profit = Selling Price − Cost Price
#
# Algebra helps us solve unknown values.

# %% [markdown]
# ## `What is Linear Algebra?`
#
# `Linear Algebra` is a branch of mathematics that studies:
#
# - Vectors
# - Matrices
# - Linear Equations
# - Vector Spaces
# - Transformations
#
# **Adv:** Instead of solving only one equation, Linear Algebra helps solve thousands or even millions of equations simultaneously.
#
# This is exactly what ML models need.

# %% [markdown]
# #### Question 1 : Two Friends Racing
#
# Rahul and Aman are two friends who decide to travel to the same destination. Rahul starts first at a speed of 60 km/h. Aman begins his journey one hour later at a speed of 80 km/h.
#
# Find a Solution:
#
# Will Aman ever catch up to Rahul?

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,8,300)

d_R = 60*t

d_A = 80 * (t-1)

meeting_point = (4,240)
plt.title("Aman vs Rahul Meeting Plot")
plt.plot(t,d_R,"--", label= "Rahul 60km/h")
plt.plot(t,d_A, "--", label = "Aman 80km/h")
plt.ylabel("Distance (KM)")
plt.xlabel("Time (hour)")
plt.annotate("meeting point",(4,240))
plt.plot(4,240,"ro",label="Intersection")
plt.legend()
plt.show()

# %%
# Out:
# [-80.         -77.85953177 -75.71906355 -73.57859532 -71.43812709
#  -69.29765886 -67.15719064 -65.01672241 -62.87625418 -60.73578595
#  -58.59531773 -56.4548495  -54.31438127 -52.17391304 -50.03344482
#  -47.89297659 -45.75250836 -43.61204013 -41.47157191 -39.33110368
#  -37.19063545 -35.05016722 -32.909699   -30.76923077 -28.62876254
#  -26.48829431 -24.34782609 -22.20735786 -20.06688963 -17.9264214
#  -15.78595318 -13.64548495 -11.50501672  -9.36454849  -7.22408027
#   -5.08361204  -2.94314381  -0.80267559   1.33779264   3.47826087
#    5.6187291    7.75919732   9.89966555  12.04013378  14.18060201
#   16.32107023  18.46153846  20.60200669  22.74247492  24.88294314
#   27.02341137  29.1638796   31.30434783  33.44481605  35.58528428
#   37.72575251  39.86622074  42.00668896  44.14715719  46.28762542
#   48.42809365  50.56856187  52.7090301   54.84949833  56.98996656
#   59.13043478  61.27090301  63.41137124  65.55183946  67.69230769
# ...

# %% [markdown]
# ### `Applications of Linear Algebra`
#
# Linear Algebra is everywhere.
#
# Examples:
# - ML
# - AI
# - Robotics
# - Computer Vision
# - Self-Driving Cars
# - Medical Imaging

# %% [markdown]
# ### `Components of Linear Algebra`
#
# Linear Algebry topics.
#
# The most important ones are:
#
# 1. Scalars
# 2. Vectors
# 3. Matrices
# 4. Tensors
# 5. Linear Equations
# 6. Determinants
# 7. Eigenvalues
# 8. Eigenvectors
# 9. Vector Spaces
# 10. Matrix Topics one by one.

# %% [markdown]
# ## Scalar
#
# A scalar is simply a single number.
# * Example 2, 4, 67, salary, Student_CGPA
# * All these are scalars because only magnitude exists.
# No direction.

# %%
salary = 80000

# %%
print(salary)
# Out:
# 80000

# %% [markdown]
# ## Vector
#
# A vector is a mathematical representation consisting of an ordered list of numbers that indicates both its magnitude, the size or length of the vector, and its direction, showing where the vector points in space.

# %% [markdown]
# ### Vector Representation
#
# Mathematically,
#
# A vector can be written as:
#
# v = [34,78]
#
# or
#
# ⎡34⎤
# ⎣78⎦
#
# Each number is called a component.

# %%
import numpy as np

# %%
 arr1 = np.array([1,3,4])

# %%
arr1
# Out:
# array([1, 3, 4])

# %%
np.arange(2,20,3)
# Out:
# array([ 2,  5,  8, 11, 14, 17])

# %%
np.arange(1,3,1.2)
# Out:
# array([1. , 2.2])

# %%
import numpy as np

row = np.array([1,2,3]) ## row vector
column = np.array([[1],[2],[3]]) ## column vector
zero = np.zeros(3) ## zero vector

# %%
row
# Out:
# array([1, 2, 3])

# %%
column
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
zero
# Out:
# array([0., 0., 0.])

# %% [markdown]
# ### Vector Addition
# * \[ A + B \]
# $$
# \mathbf{A} + \mathbf{B} = (A_1 + B_1,\; A_2 + B_2,\; \ldots,\; A_n + B_n)
# $$

# %%
vect1 = np.array([1,3,4])
vect2 = np.array([1,2,3])

# %%
vect1+vect2
# Out:
# array([2, 5, 7])

# %% [markdown]
# ### Vector Subtraction
# * \[ A - B \]
# $$
# \mathbf{A} - \mathbf{B} = (A_1 - B_1,\; A_2 - B_2,\; \ldots,\; A_n - B_n)
# $$

# %%
vect1-vect2
# Out:
# array([0, 1, 1])

# %%
# find the magnitude value?
vect1
# Out:
# array([1, 3, 4])

# %% [markdown]
# ### Scalar Multiplication
# * \[ A * c \]
# $$
# c\,\mathbf{A} = (cA_1,\; cA_2,\; \ldots,\; cA_n)
# $$

# %%
vect1*9
# Out:
# array([ 9, 27, 36])

# %% [markdown]
# ### Norm (Magnitude / Length)
# $$
# \|\mathbf{A}\| = \sqrt{A_1^2 + A_2^2 + \cdots + A_n^2}
# $$

# %%
np.linalg.norm(vect1)
# Out:
# 5.0990195135927845

# %% [markdown]
# ### Dot Product
# $$
# \mathbf{A} \cdot \mathbf{B} = A_1 B_1 + A_2 B_2 + \cdots + A_n B_n
# $$
#
# **Applications:**
#
# - Similarity Measurement
# - Recommendation Systems
# - Deep Learning
# - Cosine Similarity
# - Important Feature Selection

# %%
np.dot(vect1,vect2)
# Out:
# 19
