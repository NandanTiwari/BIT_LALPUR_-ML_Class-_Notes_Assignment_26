# %% [markdown]
# #### `Importing necessary libraries`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/ANMOLPC/Desktop/DATASET/Data_for_MultpleRegression.csv")

# %%
data.head()
# Out:
#    Interest Rate  Unemployment Rate  Stock Price
# 0            3.4                6.5         2300
# 1            3.4                6.5         2300
# 2            3.3                6.5         2300
# 3            3.2                6.4         2210
# 4            3.2                6.4         2210

# %%
y= data['Stock Price']

# %%
y.head()
# Out:
# 0    2300
# 1    2300
# 2    2300
# 3    2210
# 4    2210
# Name: Stock Price, dtype: int64

# %%
x= data['Unemployment Rate']

# %%
x.head()
# Out:
# 0    6.5
# 1    6.5
# 2    6.5
# 3    6.4
# 4    6.4
# Name: Unemployment Rate, dtype: float64

# %%
X1= np.array(x)
Y= np.array(y)

# %%
w0 = np.random.random()
w1 = np.random.random()
w0,w1
# Out:
# (0.667049578042557, 0.5751843827483988)

# %%
y_pred = w0+w1*X1

# %%
y_pred
# Out:
# array([4.40574807, 4.40574807, 4.40574807, 4.34822963, 4.34822963,
#        4.11815587, 4.11815587, 4.06063744, 4.06063744, 4.06063744,
#        4.06063744, 3.94560056, 3.94560056, 3.94560056, 3.77304524,
#        3.77304524, 3.77304524, 3.77304524, 3.71552681, 3.54297149,
#        3.54297149, 3.60048993, 3.65800837, 3.65800837, 3.48545305,
#        3.42793462, 3.42793462, 3.37041618])

# %%
pd.DataFrame({"Real":y, "Predicted":y_pred}).head(10)
# Out:
#    Real  Predicted
# 0  2300   4.405748
# 1  2300   4.405748
# 2  2300   4.405748
# 3  2210   4.348230
# 4  2210   4.348230
# 5  2210   4.118156
# 6  2210   4.118156
# 7  2190   4.060637
# 8  2190   4.060637
# 9  2190   4.060637

# %%
loss = sum((y_pred-y)**2)/len(X1)
loss
# Out:
# 4258151.914357002

# %%
alpha = 0.001
k = 0
while(k<1000):
    k+=1
    y_pred =w0+w1*X1
    j = sum((y_pred-y)**2)/len(X1)
    dj0 =(2/len(X1))*sum(y_pred-y)
    dj1 =(2/len(X1))*sum((y_pred-y)*X1)
    w0 = w0-alpha*dj0
    w1 = w1-alpha*dj1

# %%
y_pred
# Out:
# array([2378.81152093, 2378.81152093, 2378.81152093, 2343.31532387,
#        2343.31532387, 2201.33053565, 2201.33053565, 2165.8343386 ,
#        2165.8343386 , 2165.8343386 , 2165.8343386 , 2094.84194449,
#        2094.84194449, 2094.84194449, 1988.35335333, 1988.35335333,
#        1988.35335333, 1988.35335333, 1952.85715627, 1846.36856511,
#        1846.36856511, 1881.86476217, 1917.36095922, 1917.36095922,
#        1810.87236806, 1775.376171  , 1775.376171  , 1739.87997395])

# %%
predicted = pd.DataFrame({"Real":y,"Predicted":y_pred})

# %%
predicted.head(10)
# Out:
#    Real    Predicted
# 0  2300  2378.811521
# 1  2300  2378.811521
# 2  2300  2378.811521
# 3  2210  2343.315324
# 4  2210  2343.315324
# 5  2210  2201.330536
# 6  2210  2201.330536
# 7  2190  2165.834339
# 8  2190  2165.834339
# 9  2190  2165.834339

# %%
predicted.plot()
# Out:
# <Axes: >

# %%
# let see Model Accuracy 
from sklearn.metrics import r2_score
r2_score(y_pred,y)
# Out:
# 0.8624924591857993

# %%
mse=sum((y_pred-y)**2)/len(X1)
mse
# Out:
# 5283.446973174946

# %%
print("Intercept:",w0)
# Out:
# Intercept: 71.56652035708689

# %%
print("coefficient:",w1)
# Out:
# coefficient: 354.9605875523938

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
y= np.array(y)
X1 =X1.reshape(-1,1)
y = y.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X1,y, test_size=0.30, random_state=10)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluating the Linear Regression model
print("Linear Regression R^2:", lin_reg.score(X_test, y_test))
lin_reg_pred = lin_reg.predict(X_test)
# Out:
# Linear Regression R^2: 0.653882260723647

# %%
lin_reg.coef_
# Out:
# array([[286.30136986]])

# %%
lin_reg.intercept_
# Out:
# array([445.86878154])
