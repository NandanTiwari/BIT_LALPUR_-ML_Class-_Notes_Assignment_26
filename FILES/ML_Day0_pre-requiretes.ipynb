# %% [markdown]
# ## `Machine Learning Prerequisites: Python Essentials`

# %% [markdown]
# ### `1. Python Core Language (The Basics)`
# * **`Data Types`**: Strings, integers, floats, and booleans.
# * **`Data Structures`**: Lists, dictionaries, tuples, and sets.
# * **`Control Flow`**: `if-else` statements, `for` loops, and `while` loops.
# * **`Functions`**: Defining functions, arguments, and `lambda` (anonymous) functions.
# * **`List Comprehensions`**: Writing concise, single-line loops for data transformation.
#
# http://localhost:8888/lab/tree/Desktop/Python_Teach/Introduction%20to%20Python%20(Day1).ipynb

# %% [markdown]
# ### `2. Object-Oriented Programming (OOP)`
# * **`Classes & Objects`**: Understanding how to define blueprints and instantiate objects.
# * **`Attributes & Methods`**: Variables and functions tied specifically to an object.
# * **`Inheritance`**: Creating child classes that inherit properties from parent classes.

# %% [markdown]
# http://localhost:8888/lab/tree/Python_Teach/class.ipynb

# %% [markdown]
# ### `3. Essential ML Libraries`
# * **`NumPy`**: Handling multi-dimensional arrays, vectorization, and matrix mathematics.
# * **`Pandas`**: Managing structured data using DataFrames, filtering, and handling missing values.
# * **`Polars`**: Processing massive datasets rapidly using a fast, multi-threaded DataFrame library.
# * **`Matplotlib` & `Seaborn`**: Creating line plots, scatter plots, histograms, and heatmaps.

# %% [markdown]
# ### 4. `Code & Environment Management`
# * **`Jupyter Notebooks`**: Running and documenting code in interactive, cell-based environments.
# * **`Google Colab`**: Executing code in a cloud-based Jupyter environment with free access to GPUs and TPUs.
# * **`Pip` / `Conda`**: Installing packages and managing virtual environments.

# %%
student_marks = {"Vivek":{"math": 45, "Hindi":86}, "sahil":{"math": 34, "Hindi":78}}
for i ,j in student_marks.items():
    print("Name:", i)
    for sub,marks in j.items():
        print(sub,marks)
# Out:
# Name: Vivek
# math 45
# Hindi 86
# Name: sahil
# math 34
# Hindi 78

# %%
student_marks.items

# %%
i=0
while(" "):
    print("HEllo BIT")
